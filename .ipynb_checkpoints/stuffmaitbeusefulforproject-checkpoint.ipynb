# %% [markdown]
# ORF 350 HW 7 Georgy Noarov (gnoarov) Collaborators: only myself

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os, sys
import string, re

from sklearn.model_selection import train_test_split
from sklearn import metrics

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import word_tokenize

from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import spacy
spacy.load('en')
lemmatizer = spacy.lang.en.English()

# %%
a = np.load("embeddings.npz")
real_word2ind = {}
word2ind = a["word2ind"].flatten()[0]
for k in word2ind:
    real_word2ind[word2ind[k]] = k
emb = a["emb"]

def get_embedding(word):
    if word in real_word2ind:
        return emb[real_word2ind[word],]
    return np.zeros((128))

#print(get_embedding('sit'))
#print(get_embedding('book'))

def word2vec_avg(doc):
    doc = my_preprocessor(doc)
    tokenized_words = word_tokenize(doc)
    avg_emb = np.zeros((128))
    for word in tokenized_words:
        avg_emb += get_embedding(word)
    return avg_emb/len(tokenized_words)

def word2vec_np(df):
    return np.array([word2vec_avg(doc) for doc in df['text']])

def simple_classifiers_word2vec_pca(df, n_comps):
    df = df.reset_index()
    a, b, c, d = train_test_split(range(1, 41), range(1, 41), test_size=0.2, random_state=42)
    
    reduced_data = PCA(n_comps).fit_transform(word2vec_np(df))
    df_train = df[df['num'].isin(a)]
    df_test = df[df['num'].isin(b)]
    
    X_train = reduced_data[df.index[df['num'].isin(a)]]
    X_test = reduced_data[df.index[df['num'].isin(b)]]
    y_train = df_train['type']
    y_test = df_test['type']
    
#     clf_mnb = MultinomialNB().fit(X_train, y_train)
#     predicted_mnb = clf_mnb.predict(X_test)
#     print("MultinomialNB Accuracy:",metrics.accuracy_score(y_test, predicted_mnb))
    
    clf_lreg = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial').fit(X_train, y_train)
    predicted_lreg = clf_lreg.predict(X_test)
    print("Logistic Regression Accuracy:", metrics.accuracy_score(y_test, predicted_lreg))
    
    clf_svm = LinearSVC(random_state=0, tol=1e-5).fit(X_train, y_train)
    predicted_svm = clf_svm.predict(X_test)
    print("Linear SVM Accuracy:", metrics.accuracy_score(y_test, predicted_svm))

simple_classifiers_word2vec_pca(df_edu, 7)

# labels_color_map = {
#    0: '#20b2aa', 1: '#ff7373', 2: '#ffe4e1', 3: '#005073', 4: '#4d0404',
#    5: '#ccc0ba', 6: '#4700f9', 7: '#f6f900', 8: '#00f91d', 9: '#da8c49'
# }

# fig, ax = plt.subplots()
# colors = iter(cm.rainbow(np.linspace(0, 1, 40)))
# for index, instance in enumerate(reduced_data):
#     # print instance, index, labels[index]
#     pca_comp_1, pca_comp_2 = reduced_data[index]
#     ax.scatter(pca_comp_1, pca_comp_2, color=labels_color_map[df_edu['type'].values[index]])
# plt.show()

# simple_classifiers(df_edu, )
# Out:
# Logistic Regression Accuracy: 0.6875
# Linear SVM Accuracy: 0.625

# %%
def print_topfeatures(vectorizer, clf):
    """Prints features with the highest coefficient values, per class"""
    feature_names = vectorizer.get_feature_names()
    print("Number of features: ", len(feature_names))
    topfeatures_real = np.argsort(clf.coef_[0])[-10:]
    topfeatures_fake = np.argsort(clf.coef_[0])[0:10]
    
    print("Words most indicative of real news: %s" % (" ".join(feature_names[j] for j in topfeatures_real)))
    print("Words most indicative of fake news: %s" % (" ".join(feature_names[j] for j in topfeatures_fake)))

def simple_classifiers(df, vectorizer):
    
    vectorizer = vectorizer.fit(df['text'])
    
    a, b, c, d = train_test_split(range(1, 41), range(1, 41), test_size=0.2, random_state=42)
    
    df_train = df[df['num'].isin(a)]
    df_test = df[df['num'].isin(b)]
    
    X_train = vectorizer.transform(df_train['text'])
    X_test = vectorizer.transform(df_test['text'])
    y_train = df_train['type']
    y_test = df_test['type']
    
    clf_mnb = MultinomialNB().fit(X_train, y_train)
    predicted_mnb = clf_mnb.predict(X_test)
    print("MultinomialNB Accuracy:",metrics.accuracy_score(y_test, predicted_mnb))
    
    clf_lreg = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial').fit(X_train, y_train)
    predicted_lreg = clf_lreg.predict(X_test)
    print("Logistic Regression Accuracy:", metrics.accuracy_score(y_test, predicted_lreg))
    
    clf_svm = LinearSVC(random_state=0, tol=1e-5).fit(X_train, y_train)
    predicted_svm = clf_svm.predict(X_test)
    print("Linear SVM Accuracy:", metrics.accuracy_score(y_test, predicted_svm))
    
    print_top10(vectorizer, clf_svm)
    
    #for i in vectorizer.get_feature_names():
    #    print(i)
    #    print(wm2df(tf_edu, vectorizer.get_feature_names()))
    
def simple_classifiers_for_each_area(vectorizer):
    print("On Education:")
    simple_classifiers(df_edu, vectorizer)
    print()
    print("On Business:")
    simple_classifiers(df_biz, vectorizer)
    print()
    print("On Entertainment:")
    simple_classifiers(df_ent, vectorizer)
    print()
    print("On Sports:")
    simple_classifiers(df_spo, vectorizer)
    print()
    print("On Politics:")
    simple_classifiers(df_pol, vectorizer)
    print()
    print("On Tech:")
    simple_classifiers(df_tec, vectorizer)
    
    return vectorizer.transform(df_edu['text'])

# %%
# this code, used to read in the data, comes from my own work for a different course

# fake news dataset with different genres
directory_real = os.fsencode('./fakeNewsDatasets/fakeNewsDataset/legit')
directory_fake = os.fsencode('./fakeNewsDatasets/fakeNewsDataset/fake')
real_news = os.fsdecode(directory_real)
fake_news = os.fsdecode(directory_fake)

files_real = [[open(real_news + '/' + os.fsdecode(file), 'r', encoding='utf-8-sig').read(), \
               os.fsdecode(file)[:3], int(''.join(c for c in os.fsdecode(file) if c.isdigit()))] \
              for file in os.listdir(directory_real)]
files_fake = [[open(fake_news + '/' + os.fsdecode(file), 'r', encoding='utf-8-sig').read(), \
               os.fsdecode(file)[:3], int(''.join(c for c in os.fsdecode(file) if c.isdigit()))] \
              for file in os.listdir(directory_fake)]

df_misc = pd.concat([pd.DataFrame([[0, file[0], file[1], file[2]]], columns=['type','text','area', 'num']) \
                         for file in files_real] + 
                         [pd.DataFrame([[1, file[0], file[1], file[2]]], columns=['type', 'text', 'area', 'num']) \
                          for file in files_fake], ignore_index=True)

# fake news dataset on celebrities
directory_real = os.fsencode('./fakeNewsDatasets/celebrityDataset/legit')
directory_fake = os.fsencode('./fakeNewsDatasets/celebrityDataset/fake')
real_news = os.fsdecode(directory_real)
fake_news = os.fsdecode(directory_fake)

files_real = [open(real_news + '/' + os.fsdecode(file), 'r', encoding='utf-8-sig').read() \
              for file in os.listdir(directory_real)]
files_fake = [open(fake_news + '/' + os.fsdecode(file), 'r', encoding='utf-8-sig').read() \
              for file in os.listdir(directory_fake)]

df_celebr = pd.concat([pd.DataFrame([[0, file]], columns=['type', 'text']) for file in files_real] + 
                         [pd.DataFrame([[1, file]], columns=['type', 'text']) for file in files_fake], \
                         ignore_index=True)

# %%
X_train, X_test, y_train, y_test = \
    train_test_split(range(1, 41), range(1, 41), test_size=0.3, random_state=42)
print(X_train)
print(df_misc['text'].loc[(df_misc['area'] == 'ent') & (df_misc['num'] == 35)])
# let us look at news that are on education and are real
print(df_misc['text'].loc[(df_misc['area'] == 'edu') & (df_misc['type'] == 0)])
# Out:
# [14, 32, 35, 9, 18, 25, 1, 34, 6, 12, 2, 30, 22, 3, 31, 37, 4, 36, 24, 33, 11, 23, 19, 21, 8, 15, 29, 39]
# 92     Millie Bobby Brown taking a 'rest' between app...
# 288    Millie Bobby Brown checks into rehab after can...
# Name: text, dtype: object
# 0      Protesters Disrupt DeVos School Visit\n\n\nPro...
# 3      Trump's Pick for Education Could Face Unusuall...
# 5      School Starts Too Early In The Morning, State ...
# 7      Wi-Fi Microscopes Help Texas Students With Sci...
# 20     Arne Duncan Blasts Trump Administration Over T...
# 26     Healthier Cereals Snare a Spot on New York Sch...
# 32     Toronto Cancels U.S. Class Trips Due To Trump ...
# 35     6-year-old got gun at LA-area school; families...
# 36     Administration Sets New Rules for Federal Chil...
# 37     You've Been Accepted to Columbia. Oops, Our Er...
# 47     School Choice Fails to Make a Difference\n\nTh...
# 62     Supreme Court Expands Rights for Students with...
# 64     Universities Push Back Against Trump on Immigr...
# 68     Immigration Controversy Could Drive Up College...
# 71     Hillary Clinton To Deliver Wellesley College's...
# 78     A Tumultuous Beginning\n\nIt's been a rocky st...
# 93     STEM Students Create Winning Invention\n\nSTRE...
# 94     Scientists Bristle at Trump Budget's Cuts to R...
# 95     Exchange students say U.S. high schools easier...
# 99     Betsy DeVos's Education Hearing Erupts Into Pa...
# 102    The Teacher Shortage Crisis Is Here\n\n\nAs st...
# 122    Harvard Law, Moving to Diversify Applicant Poo...
# 123    Schools in rural areas shifting toward a 4-day...
# 126    Girls Who Code Closing Computer Science Gender...
# 129    Survey Finds College Applications from Interna...
# 150    Microsoft Aims to Build on 'Minecraft' Success...
# 154    Survey: Most Freshmen Are Not Emotionally Prep...
# 157    5-year-old wins Oklahoma spelling bee, heading...
# 164    How does nutrition affect children's school pe...
# 179    Educators Prepare for Immigration Agents at th...
# 180    Students Experiment With Drones for 4-H Nation...
# 184    This Teacher Has Personalized Handshakes For A...
# 185    Schools Use Technology to Improve Gym Classes\...
# 186    Study: Inclusive Environment Key to Closing ST...
# 208    On 'Day Without Women,' Two Districts Cancel S...
# 211    Even Preschoolers Face Racial Bias, Study Find...
# 213    Ex-US Attorney Barbara McQuade will teach law ...
# 216    Google commits $50 million to close the educat...
# 228    Sex Toy-Wielding Students Protest Gun Law at U...
# 234    How Companies and Colleges Can Get the U.S. Ba...
# Name: text, dtype: object

# %%
# let us look at the celebrity-themed dataset
print(df_celebr)
# Out:
#      type                                               text
# 0       0  Angelina Jolie, Unbroken\n\n“I never expect to...
# 1       0  Late-Night Hosts React to O.J. Simpson Parole ...
# 2       0  The new directions of One Direction: what do t...
# 3       0  'I was boozing too much': Brad Pitt talks abou...
# 4       0  'Au revoir for now': Kate and Wills bid a fond...
# 5       0  Miley Cyrus Reflects on Her Breakup With Liam ...
# 6       0  Zayn on Taylor Swift: "I Think She Deserves He...
# 7       0  Moving fashion forward: Brooding Tom Hiddlesto...
# 8       0  'Please make babies!' Fans go into overdrive a...
# 9       0  Jennifer Lopez teases Bye Bye Birdie, NBC's ne...
# 10      0  https://www.vanityfair.com/style/2017/09/jim-c...
# 11      0  It Appears Selena Gomez Just Adopted a New Pup...
# 12      0  Kanye West Celebrates 40th Birthday With Kim K...
# 13      0  \nInside Ben Affleck and Jennifer Garner's Fam...
# 14      0  Obama Says Leaving Malia at College Was ‘Like ...
# 15      0  Watch Barack Obama's sweet surprise for Michel...
# 16      0  Jennifer Aniston Finally Pregnant At 48 Years ...
# 17      0  Jennifer Aniston: I'm Not a 'Sad, Childless Hu...
# 18      0  'THE MORE THE MERRIER' Lindsay Lohan wants tal...
# 19      0  Lady Gaga is not pregnant, says representative...
# 20      0  Ellen DeGeneres sends her producer to another ...
# 21      0  Brad Pitt, Angelina Jolie Lose Court Case Over...
# 22      0  Inside Beyoncé's baby shower\n\nDon't act like...
# 23      0  Love is in the air! Charlize Theron and Sean P...
# 24      0  ‘Megyn Kelly Today’ Ratings Not All Sunshine f...
# 25      0  Jim Carrey Says He Has Sailed a 'River of Sorr...
# 26      0  Lindsay Lohan Is Reportedly Engaged To Russian...
# 27      0  Gwen Stefani Will Reunite with Boyfriend Blake...
# 28      0  Nicki Minaj Did NOT Wear Hot Pants And Crop To...
# 29      0  Taylor Swift Debuts a Bold Makeunder on Her Re...
# ..    ...                                                ...
# 470     1  Selena Gomez being eyed as 'American Idol' jud...
# 471     1  Will Kim Kardashian Divorce Kanye West?\n\nKim...
# 472     1  BRAD PITT : No Doubt, TRUMP Will Be The Best P...
# 473     1  Angelina Jolie's French Obsession\n\nAngelina ...
# 474     1  EXCLUSIVE PICS: First photos of Ariana Grande ...
# 475     1  Leah Remini Opens Up About Her Friendship With...
# 476     1  \nTaylor Swift Goes Naked in '...Ready for It?...
# 477     1  Ben Affleck's Life After Divorce — Embracing N...
# 478     1  Are Kendall, Kylie Jenner and Gigi, Bella Hadi...
# 479     1  BREAKING: Drake Reportedly Had A 'WEED OVERDOS...
# 480     1  It's Over! Jennifer Lawrence & Darren Aronofsk...
# 481     1  Jennifer Aniston's Diva Set Behavior - Won't E...
# 482     1  Has Tom Hiddleston's 'Embarrassing' Romance Wi...
# 483     1  Pop insiders claim Justin Bieber cancelled lon...
# 484     1  Jessica Biel and Justin Timberlake on the brin...
# 485     1  Face Lift, Botox, Peels, Oh My! Ellen DeGenere...
# 486     1  Liza Minelli Has 'Three Months Left' To Live A...
# 487     1  Jennifer Lopez & A-Rod Wedding On The Way? He ...
# 488     1  Teresa Giudice Running For New Jersey Governor...
# 489     1  JENNIFER ANISTON HINTS AT FRIENDS REUNION\n\nJ...
# 490     1  Jim Carrey Claims Donald Trump Is A 'Reptilian...
# 491     1  PINK & LADY GAGA ARE ‘WORKING TOGETHER’ TO WRI...
# 492     1  \nMel Gibson: Hollywood Pedophiles Have Nowher...
# 493     1  Ellen DeGeneres Dines With Mystery Brunette Am...
# 494     1  Barack & Michelle Obama's Marriage Meltdown - ...
# 495     1  It's All About The Ka$h! Kim Kardashian & Kany...
# 496     1  Aquaman actresses Nicole Kidman and Amber Hear...
# 497     1  Kendall Jenner: Why She’s Quitting ‘KUWTK’ But...
# 498     1  Mariah Carey’s manager was always hungry for f...
# 499     1  Malia Obama Has Barack And Michelle Worried – ...
#
# [500 rows x 2 columns]

# %%
# create dataframe for each subject
df_edu = df_misc.loc[df_misc['area'] == 'edu']
df_biz = df_misc.loc[df_misc['area'] == 'biz']
df_ent = df_misc.loc[df_misc['area'] == 'ent']
df_spo = df_misc.loc[df_misc['area'] == 'spo']
df_pol = df_misc.loc[df_misc['area'] == 'pol']
df_tec = df_misc.loc[df_misc['area'] == 'tec']
#for i in [(str(a) + ' ' + str(b)) for a, b in zip(range(80), df_edu['text'].values)]:
    #print(i)

# %%
# do multinomial naive bayes on tfidf
tf=TfidfVectorizer()
simple_classifiers_for_each_area(tf)
# Out:
# On Education:
# MultinomialNB Accuracy: 0.875
# Logistic Regression Accuracy: 0.875
# Linear SVM Accuracy: 0.9375
# Words most indicative of real news: with being creationism not be us was their have the
# Words most indicative of fake news: for about in through reports protest students districts survey columbia
#
# On Business:
# MultinomialNB Accuracy: 0.625
# Logistic Regression Accuracy: 0.625
# Linear SVM Accuracy: 0.625
# Words most indicative of real news: supports these has companies not going despite are their they
# Words most indicative of fake news: its said data before million two hard by go was
#
# On Entertainment:
# MultinomialNB Accuracy: 0.6875
# Logistic Regression Accuracy: 0.6875
# Linear SVM Accuracy: 0.6875
# Words most indicative of real news: train to no the movie they will stated way time
# Words most indicative of fake news: said she thin it in them than years released apartment
#
# On Sports:
# MultinomialNB Accuracy: 0.625
# Logistic Regression Accuracy: 0.625
# Linear SVM Accuracy: 0.5625
# Words most indicative of real news: giving jordan friendship my other each had game have that
# Words most indicative of fake news: women for ban on amateur people herself but lot by
#
# On Politics:
# MultinomialNB Accuracy: 0.6875
# Logistic Regression Accuracy: 0.625
# Linear SVM Accuracy: 0.625
# Words most indicative of real news: women out this love are is be he has that
# Words most indicative of fake news: administration mr said its according official you hand as always
#
# On Tech:
# MultinomialNB Accuracy: 0.625
# Logistic Regression Accuracy: 0.625
# Linear SVM Accuracy: 0.625
# Words most indicative of real news: automated this was is into would has had many be
# Words most indicative of fake news: said on its up at see year autonomous company ads
# <80x2320 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3773 stored elements in Compressed Sparse Row format>

# %%
# do multinomial naive bayes on tf
token = RegexpTokenizer(r'[a-zA-Z0-9]+')
cv = CountVectorizer(lowercase=True, stop_words='english', ngram_range = (1,1), tokenizer = token.tokenize)

simple_classifiers_for_each_area(cv)
# Out:
# On Education:
# MultinomialNB Accuracy: 0.8125
# Logistic Regression Accuracy: 0.6875
# Linear SVM Accuracy: 0.6875
# Words most indicative of real news: new trump effort presidency creationism degree according mistress liberal clinton
# Words most indicative of fake news: s districts protest t district reports black toy members college
#
# On Business:
# MultinomialNB Accuracy: 0.6875
# Logistic Regression Accuracy: 0.5625
# Linear SVM Accuracy: 0.5625
# Words most indicative of real news: showing improved despite 0 00 big accepted bought sale sell
# Words most indicative of fake news: buy said s launched hard fine 129m 235m data cut
#
# On Entertainment:
# MultinomialNB Accuracy: 0.5625
# Logistic Regression Accuracy: 0.5
# Linear SVM Accuracy: 0.5
# Words most indicative of real news: dates deny court movie public refused fans way time cfo
# Words most indicative of fake news: offered said years executive network s think taking space died
#
# On Sports:
# MultinomialNB Accuracy: 0.5625
# Logistic Regression Accuracy: 0.625
# Linear SVM Accuracy: 0.625
# Words most indicative of real news: reasonable considering friendship july men injury game new told giving
# Words most indicative of fake news: lot harm claims women ban apologised guess june 2020 spanish
#
# On Politics:
# MultinomialNB Accuracy: 0.5625
# Logistic Regression Accuracy: 0.6875
# Linear SVM Accuracy: 0.75
# Words most indicative of real news: went great evidence america increased asked nationalist white just love
# Words most indicative of fake news: said administration according mr east middle state importance plan ban
#
# On Tech:
# MultinomialNB Accuracy: 0.5625
# Logistic Regression Accuracy: 0.5
# Linear SVM Accuracy: 0.5
# Words most indicative of real news: people old tablets order taken world elites scientist user event
# Words most indicative of fake news: said year scientists just company week autonomous t thursday security
# <80x2128 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1922 stored elements in Compressed Sparse Row format>

# %%
import nltk

from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()

from nltk.stem.porter import PorterStemmer
stem = PorterStemmer()

word = "flying"
print("Lemmatized Word:",lem.lemmatize(word,"v"))
print("Stemmed Word:",stem.stem(word))
# Out:
# Lemmatized Word: fly
# Stemmed Word: fli

# %%
# create a dataframe from a word matrix: this function found online
def wm2df(wm, feat_names):
    
    # create an index for each row
    doc_names = ['Doc{:d}'.format(idx) for idx, _ in enumerate(wm)]
    df = pd.DataFrame(data=wm.toarray(), index=doc_names,
                      columns=feat_names)
    return(df)

#from nltk.tokenize import word_tokenize
#token_edu = word_tokenize("jjswfgij asijfpioa poajsfiop")
#print(token_edu)

def my_preprocessor(doc):
    #print(doc)
    #print(' '.join(doc.lower().split()))
    #return ' '.join(doc.lower().split())
    #return re.sub('\n+', ' ', doc.lower())
    s = ' '.join(doc.lower().split())
    #print(re.sub(' +', ' ', re.sub('[0-9]+', '', s.translate(str.maketrans('', '', string.punctuation)))))
    return re.sub(' +', ' ', re.sub('[0-9]+', '', s.translate(str.maketrans('', '', string.punctuation))))

def get_lemma(token):
    if token.lemma_.isdigit():
        return token.text.lower()
    if token.pos_ == 'PRON' or token.lemma_ == '-PRON-':
        return token.text.lower()
    return token.lemma_.lower()

def my_tokenizer(doc):
    tokens = lemmatizer(doc)
    #return [token.lemma_ for token in tokens]
    return [get_lemma(token) for token in tokens]

tfidf = TfidfVectorizer(lowercase=True, strip_accents='unicode', \
                        tokenizer=my_tokenizer, ngram_range=(1, 1), preprocessor=my_preprocessor)

tfidf_matrix = simple_classifiers_for_each_area(tfidf)
X = tfidf_matrix.todense()

clustering_model = KMeans(
    n_clusters=2,
    precompute_distances="auto",
    n_jobs=-1
)

predicted_kmeans = clustering_model.fit_predict(X)
print(len(predicted_kmeans))
print(metrics.accuracy_score(df_edu['type'], predicted_kmeans))

reduced_data = PCA(n_components=2).fit_transform(X)
# print reduced_data

#labels_color_map = {
#   0: '#20b2aa', 1: '#ff7373', 2: '#ffe4e1', 3: '#005073', 4: '#4d0404',
#   5: '#ccc0ba', 6: '#4700f9', 7: '#f6f900', 8: '#00f91d', 9: '#da8c49'
#}

import matplotlib.cm as cm

fig, ax = plt.subplots()
colors = iter(cm.rainbow(np.linspace(0, 1, 40)))
for index, instance in enumerate(reduced_data):
    # print instance, index, labels[index]
    pca_comp_1, pca_comp_2 = reduced_data[index]
    print(index)
    x = df_edu['num'].values
    col = 1/x[index]#labels_color_map[df_edu['type'].values[index]]
    print(col)
    
    #colors = iter(cm.rainbow(np.linspace(0, 1, len(ys))))
    #for y in ys:
    #    plt.scatter(x, y, color=next(colors))
    ax.scatter(pca_comp_1, pca_comp_2, color=col)
plt.show()
# Out:
# On Education:
# MultinomialNB Accuracy: 0.875
# Logistic Regression Accuracy: 0.9375
# Linear SVM Accuracy: 0.9375
# Words most indicative of real news: gas presidency support with this creationism their have the be
# Words most indicative of fake news: for district start in about economist through a early yearold
#
# On Business:
# MultinomialNB Accuracy: 0.6875
# Logistic Regression Accuracy: 0.75
# Linear SVM Accuracy: 0.8125
# Words most indicative of real news: this have accept support success profit not despite their they
# Words most indicative of fake news: say its £ datum high before firm hard two fine
#
# On Entertainment:
# MultinomialNB Accuracy: 0.5625
# Logistic Regression Accuracy: 0.6875
# Linear SVM Accuracy: 0.625
# Words most indicative of real news: train that dance secret show movie they will way time
# Words most indicative of fake news: i s its say thin them she than apartment would
#
# On Sports:
# MultinomialNB Accuracy: 0.6875
# Logistic Regression Accuracy: 0.75
# Linear SVM Accuracy: 0.75
# Words most indicative of real news: race game each other team friendship swarm that injury have
# Words most indicative of fake news: amateur for on people woman herself by who yearold lot
#
# On Politics:
# MultinomialNB Accuracy: 0.625
# Logistic Regression Accuracy: 0.5625
# Linear SVM Accuracy: 0.5625
# Words most indicative of real news: clinton wife note love comment this that he have be
# Words most indicative of fake news: a administration mr say hand accord standard official you set
#
# On Tech:
# MultinomialNB Accuracy: 0.8125
# Logistic Regression Accuracy: 0.8125
# Linear SVM Accuracy: 0.8125
# Words most indicative of real news: would campaign free into this defeat hand many have be
# Words most indicative of fake news: say on up at engine see it device test its
# 80
# 0.5375
# 0
# 0.1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-342-e6b6384a9dca> in <module>
#      71     #for y in ys:
#      72     #    plt.scatter(x, y, color=next(colors))
# ---> 73     ax.scatter(pca_comp_1, pca_comp_2, color=col)
#      74 plt.show()
#
# ~/anaconda3/envs/mypython3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/envs/mypython3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4141         if co is not None:
#    4142             try:
# -> 4143                 mcolors.to_rgba_array(co)
#    4144             except ValueError:
#    4145                 raise ValueError("'color' kwarg must be an mpl color"
#
# ~/anaconda3/envs/mypython3/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     271         pass
#     272     # Convert one at a time.
# --> 273     result = np.empty((len(c), 4), float)
#     274     for i, cc in enumerate(c):
#     275         result[i] = to_rgba(cc, alpha)
#
# TypeError: object of type 'numpy.float64' has no len()
